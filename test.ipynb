# %%
from models import *
from datagen import *
from utils import *
from config import *
import random
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from datagen import load_and_preprocess

# %%
# !python3 draw_img.py
# Out:
# QObject::moveToThread: Current thread (0x55fe60842fc0) is not the object's thread (0x55fe60f35d80).
# Cannot move to target thread (0x55fe60842fc0)
#
# QObject::moveToThread: Current thread (0x55fe60842fc0) is not the object's thread (0x55fe60f35d80).
# Cannot move to target thread (0x55fe60842fc0)
#
# Qt: Session management error: None of the authentication protocols specified are supported
# QObject::moveToThread: Current thread (0x55fe60842fc0) is not the object's thread (0x55fe60f35d80).
# Cannot move to target thread (0x55fe60842fc0)
#
# QObject::moveToThread: Current thread (0x55fe60842fc0) is not the object's thread (0x55fe60f35d80).
# Cannot move to target thread (0x55fe60842fc0)
#
# QObject::moveToThread: Current thread (0x55fe60842fc0) is not the object's thread (0x55fe60f35d80).
# Cannot move to target thread (0x55fe60842fc0)
#
# QObject::moveToThread: Current thread (0x55fe60842fc0) is not the object's thread (0x55fe60f35d80).
# ...

# %%
# !python3 inference_one.py
# Out:
# Using TensorFlow backend.
# 2021-04-12 13:29:58.705096: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2021-04-12 13:29:58.744989: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1006] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-12 13:29:58.745897: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: GeForce GTX 1060 major: 6 minor: 1 memoryClockRate(GHz): 1.6705
# pciBusID: 0000:01:00.0
# 2021-04-12 13:29:58.751408: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2021-04-12 13:29:58.759501: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# ...
